# %% [markdown]
# ## Algoritmo para otimização

# %%
import random
import math

# Parâmetros do problema
BOUNDS = {'h': (10.0, 100.0), 't': (1.0, 10.0), 's': (2.0, 20.0)}
PARAM_KEYS = ['h', 't', 's']

# Constantes do Algoritmo
TAM_POP = 20  #TAMANHO DA POPULAÇÃO
N_GER = 100 #N_GERAÇÕES
P_CROSSOVER = 0.8 #PROBABILIDADE DE CRUZAMENTO
P_MUT = 0.1 # PROBABILIDADE DE MUTAÇÃO
K_TORNEIO = 3 # Tamanho do torneio
TAMANHO_ELITE = 1 # Tamanho da elite

# Pesos das penalizações (mais fáceis de ajustar aqui)
PENALTY_WEIGHT_VOL = 10.0
PENALTY_WEIGHT_SUM = 10.0

# ===== Funções básicas =====

def criar_individuo():
    return [random.uniform(*BOUNDS[k]) for k in PARAM_KEYS]

def limitar_genes(ind):
    return [max(min(g, BOUNDS[k][1]), BOUNDS[k][0]) for g, k in zip(ind, PARAM_KEYS)]

def func_desempenho(h, t, s):
    return (h * math.log(s + 1)) / (t + 1)

def avaliar_individuo(ind):
    h, t, s = ind
    desempenho = func_desempenho(h, t, s)
    
    # Penalizações por violação das restrições
    viol_vol = max(0.0, h * t * s - 10000.0)
    viol_sum = max(0.0, (t + s) - 25.0)
    
    penalty = PENALTY_WEIGHT_VOL * viol_vol + PENALTY_WEIGHT_SUM * viol_sum
    return desempenho - penalty

# ===== População =====

def criar_populacao(n_individuos):
    return [criar_individuo() for _ in range(n_individuos)]

# ===== Operadores genéticos =====

def selecao_torneio(pop, fits, k):
    idxs = random.sample(range(len(pop)), k)
    best_idx_in_sample = max(idxs, key=lambda i: fits[i])
    return pop[best_idx_in_sample]

def crossover(pai, mae, fator_blend=0.5): # Variável 'alpha' renomeada para clareza
    filho = [fator_blend * x + (1 - fator_blend) * y for x, y in zip(pai, mae)]
    return limitar_genes(filho)

def mutacao_gauss(ind, sigma=0.1, p_mut_gene=0.1):
    novo_ind = []
    for gene, key in zip(ind, PARAM_KEYS):
        if random.random() < p_mut_gene:
            low, high = BOUNDS[key]
            gene += random.gauss(0, sigma * (high - low))
        novo_ind.append(gene)
    return limitar_genes(novo_ind)

# ===== Geração seguinte (Lógica de avaliação da elite corrigida) =====

def criar_nova_geracao(pop, fits):
    N = len(pop)
    
    # Elitismo: Mantém os melhores indivíduos E SEUS SCORES DE FITNESS
    idx_sorted = sorted(range(N), key=lambda i: fits[i], reverse=True)
    
    # Copia a elite (indivíduos e fitness) para a nova geração
    nova_pop = [pop[i] for i in idx_sorted[:TAMANHO_ELITE]]
    novos_fits = [fits[i] for i in idx_sorted[:TAMANHO_ELITE]]

    # Preenche o restante da população
    while len(nova_pop) < N:
        pai = selecao_torneio(pop, fits, k=K_TORNEIO)
        mae = selecao_torneio(pop, fits, k=K_TORNEIO)
        
        if random.random() < P_CROSSOVER:
            filho = crossover(pai, mae)
        else:
            filho = pai[:] # Clona o pai
            
        filho = mutacao_gauss(filho, p_mut_gene=P_MUT)
        
        nova_pop.append(filho)
        # IMPORTANTE: Avalia apenas o novo filho gerado
        novos_fits.append(avaliar_individuo(filho))
        
    return nova_pop, novos_fits

# ===== Execução =====
if __name__ == '__main__':
    # População inicial
    populacao = criar_populacao(TAM_POP)
    fitnesses = [avaliar_individuo(ind) for ind in populacao]

    print(populacao)
    print(fitnesses)
    print("Iniciando otimização...")
    # Loop de gerações
    for gen in range(N_GER):
        populacao, fitnesses = criar_nova_geracao(populacao, fitnesses)
        
        # Análise da geração
        i_best = max(range(TAM_POP), key=lambda i: fitnesses[i])
        ind_best = populacao[i_best]
        
        h,t,s = ind_best
        desempenho_puro = func_desempenho(h,t,s)
        
        print(f"G{gen:03d}: Melhor Fitness={fitnesses[i_best]:.4f} | "
              f"Desempenho Puro={desempenho_puro:.4f} | "
              f"h*t*s={h*t*s:.2f} | t+s={t+s:.2f} | "
              f"h={h:.2f}, t={t:.2f}, s={s:.2f}")

    # Resultado final
    i_final_best = max(range(TAM_POP), key=lambda i: fitnesses[i])
    melhor_final = populacao[i_final_best]
    h, t, s = melhor_final
    
    print("\n--- Otimização Concluída ---")
    print(f"Melhor Fitness Encontrado: {fitnesses[i_final_best]:.4f}")
    print(f"Melhores Parâmetros (h, t, s): ({h:.4f}, {t:.4f}, {s:.4f})")
    print(f"Restrição de Volume (h*t*s < 10000): {h*t*s:.2f}")
    print(f"Restrição de Espaço (t+s < 25): {t+s:.2f}")
# Out:
# [[41.12376278402538, 2.548608868121154, 16.836904931964106], [45.1655051188266, 9.20910974033799, 14.31538938623577], [31.107113416709552, 7.436156448716582, 16.487214026566594], [34.87115473880962, 2.795107101919243, 6.014202833316904], [18.401581420864126, 1.612358121321546, 9.83988706166426], [32.333973992816325, 8.132968467754594, 13.092951918597791], [87.96453237309795, 5.276900739518304, 4.7624747928085], [17.079376532550103, 3.6459924437705293, 12.385381066320335], [35.01042276044273, 6.482751876306592, 8.972725382756822], [63.733053821764095, 2.8835115439152377, 8.358038425053655], [25.72894375726184, 1.0320837871230135, 3.3761115994994935], [52.03600345201641, 8.682578184946214, 19.37544893180789], [34.20541314407069, 1.516185348455367, 9.261141013143135], [37.647266282312, 1.44841598199678, 16.554195946971383], [58.92894046126082, 1.5633146087554834, 18.114835552581646], [36.877241310379674, 4.246254609912553, 16.35772305335192], [38.43074618967795, 3.5156471467944708, 19.764885989262034], [98.99303406703508, 2.428615219253739, 11.194220091687784], [90.75301870921166, 7.995110613028472, 13.285065313944399], [31.037986568843067, 6.238929527388214, 19.87921516008431]]
# G018: Melhor Fitness=146.9251 | Desempenho Puro=146.9251 | h*t*s=1788.75 | t+s=18.89 | h=100.00, t=1.00, s=17.89
# G019: Melhor Fitness=146.9251 | Desempenho Puro=146.9251 | h*t*s=1788.75 | t+s=18.89 | h=100.00, t=1.00, s=17.89
# G020: Melhor Fitness=151.9928 | Desempenho Puro=151.9928 | h*t*s=1996.93 | t+s=21.00 | h=99.85, t=1.00, s=20.00
# G021: Melhor Fitness=151.9928 | Desempenho Puro=151.9928 | h*t*s=1996.93 | t+s=21.00 | h=99.85, t=1.00, s=20.00
# G022: Melhor Fitness=151.9928 | Desempenho Puro=151.9928 | h*t*s=1996.93 | t+s=21.00 | h=99.85, t=1.00, s=20.00
# G023: Melhor Fitness=151.9928 | Desempenho Puro=151.9928 | h*t*s=1996.93 | t+s=21.00 | h=99.85, t=1.00, s=20.00
# G024: Melhor Fitness=151.9928 | Desempenho Puro=151.9928 | h*t*s=1996.93 | t+s=21.00 | h=99.85, t=1.00, s=20.00
# G025: Melhor Fitness=152.1354 | Desempenho Puro=152.1354 | h*t*s=1996.20 | t+s=20.96 | h=100.00, t=1.00, s=19.96
# G026: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G027: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G028: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G029: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G030: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G031: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G032: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G033: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G034: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G035: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G036: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G037: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G038: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G039: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G040: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G041: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G042: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G043: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G044: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G045: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G046: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G047: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G048: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G049: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G050: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G051: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G052: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G053: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G054: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G055: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G056: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G057: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G058: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G059: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G060: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G061: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G062: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G063: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G064: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G065: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G066: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G067: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G068: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G069: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G070: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G071: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G072: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G073: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G074: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G075: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G076: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G077: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G078: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G079: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G080: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G081: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G082: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G083: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G084: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G085: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G086: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G087: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G088: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G089: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G090: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G091: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G092: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G093: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G094: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G095: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G096: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G097: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G098: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
# G099: Melhor Fitness=152.2261 | Desempenho Puro=152.2261 | h*t*s=2000.00 | t+s=21.00 | h=100.00, t=1.00, s=20.00
#
# --- Otimização Concluída ---
# Melhor Fitness Encontrado: 152.2261
# Melhores Parâmetros (h, t, s): (100.0000, 1.0000, 20.0000)
# Restrição de Volume (h*t*s < 10000): 2000.00
# Restrição de Espaço (t+s < 25): 21.00

# %% [markdown]
# ## Algoritmo para otimização dos hiperparâmetros

# %% [markdown]
# #### A otimização não mostrou muita mudança observável na velocidade de convergência, tendo side testado com os parametrosd otimizados e não otimizados

# %%
import optuna

def objective(trial):
    # Hiperparâmetros a otimizar
    tam_pop = trial.suggest_int("TAM_POP", 10, 100)
    n_ger = trial.suggest_int("N_GER", 50, 200)
    p_cross = trial.suggest_float("P_CROSSOVER", 0.5, 1.0)
    p_mut = trial.suggest_float("P_MUT", 0.01, 0.5)
    k_torneio = trial.suggest_int("K_TORNEIO", 2, 5)
    
    # Substitui os parâmetros globais
    global TAM_POP, N_GER, P_CROSSOVER, P_MUT, K_TORNEIO
    TAM_POP = tam_pop
    N_GER = n_ger
    P_CROSSOVER = p_cross
    P_MUT = p_mut
    K_TORNEIO = k_torneio
    
    # Rodar o algoritmo com esses hiperparâmetros
    populacao = criar_populacao(TAM_POP)
    fitnesses = [avaliar_individuo(ind) for ind in populacao]

    for _ in range(N_GER):
        populacao, fitnesses = criar_nova_geracao(populacao, fitnesses)

    best_fit = max(fitnesses)
    return -best_fit  # Minimização (Optuna sempre minimiza)

# %%
if __name__ == "__main__":
    study = optuna.create_study()
    study.optimize(objective, n_trials=50)

    print("Melhores parâmetros encontrados:")
    print(study.best_params)
# Out:
# [I 2025-07-10 16:42:57,743] A new study created in memory with name: no-name-41a4c200-7b6f-4c5c-bb43-8b7c617e7959
# [I 2025-07-10 16:42:57,785] Trial 0 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 73, 'N_GER': 58, 'P_CROSSOVER': 0.8001604424678442, 'P_MUT': 0.2586683284288873, 'K_TORNEIO': 5}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:42:57,858] Trial 1 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 78, 'N_GER': 112, 'P_CROSSOVER': 0.7848348056456069, 'P_MUT': 0.052307743005936616, 'K_TORNEIO': 5}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:42:57,892] Trial 2 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 37, 'N_GER': 116, 'P_CROSSOVER': 0.8709659869933928, 'P_MUT': 0.08947858410960027, 'K_TORNEIO': 2}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:42:57,964] Trial 3 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 65, 'N_GER': 127, 'P_CROSSOVER': 0.7665773801085605, 'P_MUT': 0.15586197726335968, 'K_TORNEIO': 4}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:42:58,097] Trial 4 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 82, 'N_GER': 185, 'P_CROSSOVER': 0.532324455804625, 'P_MUT': 0.021312537954190497, 'K_TORNEIO': 5}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:42:58,121] Trial 5 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 15, 'N_GER': 177, 'P_CROSSOVER': 0.9738505788666321, 'P_MUT': 0.487056202120489, 'K_TORNEIO': 5}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:42:58,174] Trial 6 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 86, 'N_GER': 67, 'P_CROSSOVER': 0.6057896921459051, 'P_MUT': 0.1629913443639474, 'K_TORNEIO': 5}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:42:58,282] Trial 7 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 71, 'N_GER': 162, 'P_CROSSOVER': 0.680057855724736, 'P_MUT': 0.1952701706768245, 'K_TORNEIO': 5}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:42:58,367] Trial 8 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 58, 'N_GER': 184, 'P_CROSSOVER': 0.8423291870284091, 'P_MUT': 0.4549597972311893, 'K_TORNEIO': 3}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:42:58,442] Trial 9 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 79, 'N_GER': 119, 'P_CROSSOVER': 0.7951523115835858, 'P_MUT': 0.4915518866978467, 'K_TORNEIO': 2}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:42:58,498] Trial 10 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 98, 'N_GER': 50, 'P_CROSSOVER': 0.9507116234260112, 'P_MUT': 0.3282155457689324, 'K_TORNEIO': 4}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:42:58,541] Trial 11 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 42, 'N_GER': 83, 'P_CROSSOVER': 0.6956952240925982, 'P_MUT': 0.3221795426124991, 'K_TORNEIO': 4}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:42:58,634] Trial 12 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 97, 'N_GER': 96, 'P_CROSSOVER': 0.8808242525620402, 'P_MUT': 0.27966305056442103, 'K_TORNEIO': 3}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:42:58,711] Trial 13 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 47, 'N_GER': 141, 'P_CROSSOVER': 0.6913225946556116, 'P_MUT': 0.39163857921916545, 'K_TORNEIO': 5}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:42:58,778] Trial 14 finished with value: -152.22612188617114 and parameters: {'TAM_POP':
finished with value: -152.22612188617114 and parameters: {'TAM_POP': 83, 'N_GER': 167, 'P_CROSSOVER': 0.8524804487163198, 'P_MUT': 0.13437941734546685, 'K_TORNEIO': 4}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:43:00,286] Trial 34 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 62, 'N_GER': 115, 'P_CROSSOVER': 0.5814863116421123, 'P_MUT': 0.20881037636474062, 'K_TORNEIO': 5}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:43:00,396] Trial 35 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 71, 'N_GER': 141, 'P_CROSSOVER': 0.7730234424328798, 'P_MUT': 0.010708725422064629, 'K_TORNEIO': 5}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:43:00,483] Trial 36 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 76, 'N_GER': 103, 'P_CROSSOVER': 0.8307230738108752, 'P_MUT': 0.1477685296775456, 'K_TORNEIO': 4}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:43:00,589] Trial 37 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 86, 'N_GER': 122, 'P_CROSSOVER': 0.7155635996869504, 'P_MUT': 0.07837469658337669, 'K_TORNEIO': 5}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:43:00,709] Trial 38 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 68, 'N_GER': 171, 'P_CROSSOVER': 0.8033208614140953, 'P_MUT': 0.24890492542836615, 'K_TORNEIO': 4}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:43:00,745] Trial 39 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 52, 'N_GER': 58, 'P_CROSSOVER': 0.6605339779202246, 'P_MUT': 0.19108916712051663, 'K_TORNEIO': 3}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:43:00,828] Trial 40 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 61, 'N_GER': 128, 'P_CROSSOVER': 0.9506328721179049, 'P_MUT': 0.1615073181262402, 'K_TORNEIO': 5}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:43:00,974] Trial 41 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 80, 'N_GER': 193, 'P_CROSSOVER': 0.5203713085590638, 'P_MUT': 0.036110041795770036, 'K_TORNEIO': 5}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:43:01,142] Trial 42 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 93, 'N_GER': 174, 'P_CROSSOVER': 0.5551207694339146, 'P_MUT': 0.09223641028820063, 'K_TORNEIO': 5}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:43:01,307] Trial 43 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 85, 'N_GER': 185, 'P_CROSSOVER': 0.890425657590535, 'P_MUT': 0.05453302759345981, 'K_TORNEIO': 5}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:43:01,413] Trial 44 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 59, 'N_GER': 181, 'P_CROSSOVER': 0.7550831243040902, 'P_MUT': 0.02738666473872431, 'K_TORNEIO': 4}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:43:01,471] Trial 45 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 78, 'N_GER': 50, 'P_CROSSOVER': 0.8501683768052726, 'P_MUT': 0.2940523097296287, 'K_TORNEIO': 5}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:43:01,557] Trial 46 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 69, 'N_GER': 99, 'P_CROSSOVER': 0.7933069045202968, 'P_MUT': 0.3484393169912713, 'K_TORNEIO': 5}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:43:01,708] Trial 47 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 100, 'N_GER': 154, 'P_CROSSOVER': 0.6732632931545454, 'P_MUT': 0.4531599779692245, 'K_TORNEIO': 4}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:43:01,783] Trial 48 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 67, 'N_GER': 88, 'P_CROSSOVER': 0.721212683324088, 'P_MUT': 0.11702836118124711, 'K_TORNEIO': 5}. Best is trial 0 with value: -152.22612188617114.
# [I 2025-07-10 16:43:01,887] Trial 49 finished with value: -152.22612188617114 and parameters: {'TAM_POP': 90, 'N_GER': 113, 'P_CROSSOVER': 0.6945785130660383, 'P_MUT': 0.26588417371937884, 'K_TORNEIO': 4}. Best is trial 0 with value: -152.22612188617114.
# Melhores parâmetros encontrados:
# {'TAM_POP': 73, 'N_GER': 58, 'P_CROSSOVER': 0.8001604424678442, 'P_MUT': 0.2586683284288873, 'K_TORNEIO': 5}
